# %% [markdown]
# <a href="https://colab.research.google.com/github/keilah-dot/sqlite-using-python/blob/main/play_with_tables_assingment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  from google.colab import files
  file = files.upload()
# Out:
#      <input type="file" id="files-f64ee393-ebd5-462b-a572-4efe5f1b1a43" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f64ee393-ebd5-462b-a572-4efe5f1b1a43">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import sqlite3
db = 'basketball.sqlite'
conn = sqlite3.connect(db)
print('connected to database successfull')
# Out:
# connected to database successfull

# %%
import pandas as pd
query = "SELECT * FROM sqlite_master WHERE type='table'"
table = pd.read_sql_query(query,conn)
table
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    Team_Attributes    Team_Attributes         2
# 1  table      Player_Salary      Player_Salary         5
# 2  table              Draft              Draft        36
# 3  table               Team               Team       314
# 4  table  Player_Attributes  Player_Attributes       315
# 5  table             Player             Player       617
#
#                                                  sql
# 0  CREATE TABLE `Team_Attributes` (`ID`, `ABBREVI...
# 1  CREATE TABLE `Player_Salary` (`slugSeason`, `n...
# 2  CREATE TABLE `Draft` (`yearDraft`, `numberPick...
# 3  CREATE TABLE `Team` (`id`, `full_name`, `abbre...
# 4  CREATE TABLE `Player_Attributes` (`ID`, `FIRST...
# 5  CREATE TABLE `Player` (`id`, `full_name`, `fir...

# %%
query= "SELECT * FROM Team"
team = pd.read_sql_query(query,conn)
team
# Out:
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %%
query = "SELECT * FROM team WHERE state = 'Texas' OR state = 'New York'"
team = pd.read_sql_query(query, conn)
team
# Out:
#            id          full_name abbreviation   nickname         city  \
# 0  1610612742   Dallas Mavericks          DAL  Mavericks       Dallas
# 1  1610612745    Houston Rockets          HOU    Rockets      Houston
# 2  1610612751      Brooklyn Nets          BKN       Nets     Brooklyn
# 3  1610612752    New York Knicks          NYK     Knicks     New York
# 4  1610612759  San Antonio Spurs          SAS      Spurs  San Antonio
#
#       state year_founded
# 0     Texas         1980
# 1     Texas         1967
# 2  New York         1976
# 3  New York         1946
# 4     Texas         1976

# %%
query = "SELECT * FROM Team WHERE Full_Name LIKE 'Los%'"
team = pd.read_sql_query(query,conn)
team
# Out:
#            id             full_name abbreviation  nickname         city  \
# 0  1610612746  Los Angeles Clippers          LAC  Clippers  Los Angeles
# 1  1610612747    Los Angeles Lakers          LAL    Lakers  Los Angeles
#
#         state year_founded
# 0  California         1970
# 1  California         1948

# %%
query = "SELECT Full_Name, nickname, city, year_founded FROM team WHERE year_founded >= 1990"
team = pd.read_sql_query(query, conn)
team
# Out:
#                  full_name       nickname           city year_founded
# 0            Atlanta Hawks          Hawks        Atlanta         1949
# 1           Boston Celtics        Celtics         Boston         1946
# 2      Cleveland Cavaliers      Cavaliers      Cleveland         1970
# 3     New Orleans Pelicans       Pelicans    New Orleans         2002
# 4            Chicago Bulls          Bulls        Chicago         1966
# 5         Dallas Mavericks      Mavericks         Dallas         1980
# 6           Denver Nuggets        Nuggets         Denver         1976
# 7    Golden State Warriors       Warriors   Golden State         1946
# 8          Houston Rockets        Rockets        Houston         1967
# 9     Los Angeles Clippers       Clippers    Los Angeles         1970
# 10      Los Angeles Lakers         Lakers    Los Angeles         1948
# 11              Miami Heat           Heat          Miami         1988
# ...

# %%
query = "SELECT * FROM team WHERE year_founded max"
team = pd.read_sql_query(query,conn)
team

##i can't figure how to do number 8, the max and min, earliest and latest
